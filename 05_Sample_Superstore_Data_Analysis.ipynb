# %% [markdown]
# # **Analysis Workflow**
#
#
#
# * Reading the Data from Google Sheet : [Sheet Link](https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/edit?usp=sharing)
# * Basic Exploratory Data Analysis (EDA).
# * Data Cleaning.
# * Merging with others Dim Sheets.
# * Save the final Consolidated Data in BigQuery.
#
# **Note:** Please use the left side panel of the Table of Contents to navigate through the sections.

# %% [markdown]
# # **Neccessary Libraries**

# %%
# Neccessary Libraries

# for storing data into BigQuery
from google.cloud import bigquery
from google.colab import auth

# for authenticate
# auth.authenticate_user()

# initialize the client for Bigquery
project_id = 'keen-phalanx-396514'
client = bigquery.Client(project_id, location='US')

# for Cleaning, Analyzing & Charts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re


from google.auth.transport.requests import Request
from google.oauth2.service_account import Credentials

# %% [markdown]
# **Google Sheet URLs for CSV export**
#
# To convert a google gheet file into csv and directly read by pandas here is the structure we need to follow,
# https://docs.google.com/spreadsheets/d/{spreadsheet_id}/export?format=csv&gid={sheet_gid}
#
# For example;
#
# this https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/edit?gid=1531479241#gid=1531479241
#
# will be converted to;
#
# this https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/export?format=csv&gid=1531479241

# %% [markdown]
# # **Data Explorations**

# %%
# @title Google Sheet URLs for CSV export

# file path

orders = "https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/export?format=csv&gid=1531479241"
customers = "https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/export?format=csv&gid=2099175586"
returns = "https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/export?format=csv&gid=1158708900"
users = "https://docs.google.com/spreadsheets/d/1yUCGN3Z-lywUyD3gjE2V6h_VMsOWgkfKcov65aO6e8M/export?format=csv&gid=531959115"

# Read directly into Pandas DataFrame
df_orders = pd.read_csv(orders, index_col='Order ID')
df_customers = pd.read_csv(customers)
df_returns = pd.read_csv(returns)
df_users = pd.read_csv(users)

# %%
# @title Orders

# Display the first few rows
df_orders.head()
# Out:
#           Row ID  Customer ID Customer Segment Product Category  \
# Order ID
# 88525      18606            2        Corporate  Office Supplies
# 88522      20847            3        Corporate  Office Supplies
# 88523      23086            3        Corporate  Office Supplies
# 88523      23087            3        Corporate  Office Supplies
# 88523      23088            3        Corporate       Technology
#
#                    Product Sub-Category Product Container  \
# Order ID
# 88525                            Labels         Small Box
# 88522               Pens & Art Supplies          Wrap Bag
# 88523                             Paper         Small Box
# 88523     Scissors, Rulers and Trimmers        Small Pack
# 88523      Telephones and Communication         Small Box
#
#                                             Product Name Order Priority  \
# Order ID
# 88525                                           Avery 49  Not Specified
# 88522     SANFORD Liquid Accent™ Tank-Style Highlighters           High
# 88523                                         Xerox 1968  Not Specified
# 88523           Acme® Preferred Stainless Steel Scissors  Not Specified
# 88523                                                V70  Not Specified
#
#             Ship Mode   Region  ... Postal Code Order Date  Ship Date  \
# Order ID                        ...
# 88525     Regular Air  Central  ...       60101  5/28/2012  5/30/2012
# 88522     Express Air     West  ...       98221   7/7/2010   7/8/2010
# 88523     Express Air     West  ...       98221  7/27/2011  7/28/2011
# 88523     Regular Air     West  ...       98221  7/27/2011  7/28/2011
# 88523     Express Air     West  ...       98221  7/27/2011  7/27/2011
#
#          Quantity Ordered Unit Price  Discount  Product Base Margin  \
# Order ID
# 88525                   2       2.88      0.01                 0.36
# 88522                   4       2.84      0.01                 0.54
# 88523                   7       6.68      0.03                 0.37
# 88523                   7       5.68      0.01                 0.56
# 88523                   8     205.99      0.00                 0.59
#
#           Shipping Cost    Sales    Profit
# Order ID
# 88525              0.50     5.90    1.3200
# 88522              0.93    13.01    4.5600
# 88523              6.15    49.92  -47.6400
# 88523              3.60    41.64  -30.5100
# 88523              2.50  1446.67  998.2023
#
# [5 rows x 22 columns]

# %%
# @title Customers

# Display the first few rows
df_customers.head()
# Out:
#    Customer ID    Customer Name
# 0            2  Janice Fletcher
# 1            3    Bonnie Potter
# 2            5   Ronnie Proctor
# 3            6     Dwight Hwang
# 4            7        Leon Gill

# %%
# @title Returns

# Display the first few rows
df_returns.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
# @title Users

# Display the first few rows
df_users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ## **Basic Data Cleaning**

# %%
# @title Dropping The Row ID
df_orders.drop("Row ID", axis=1, inplace=True)
df_orders.head()
# Out:
#           Customer ID Customer Segment Product Category  \
# Order ID
# 88525               2        Corporate  Office Supplies
# 88522               3        Corporate  Office Supplies
# 88523               3        Corporate  Office Supplies
# 88523               3        Corporate  Office Supplies
# 88523               3        Corporate       Technology
#
#                    Product Sub-Category Product Container  \
# Order ID
# 88525                            Labels         Small Box
# 88522               Pens & Art Supplies          Wrap Bag
# 88523                             Paper         Small Box
# 88523     Scissors, Rulers and Trimmers        Small Pack
# 88523      Telephones and Communication         Small Box
#
#                                             Product Name Order Priority  \
# Order ID
# 88525                                           Avery 49  Not Specified
# 88522     SANFORD Liquid Accent™ Tank-Style Highlighters           High
# 88523                                         Xerox 1968  Not Specified
# 88523           Acme® Preferred Stainless Steel Scissors  Not Specified
# 88523                                                V70  Not Specified
#
#             Ship Mode   Region State or Province  ... Postal Code  Order Date  \
# Order ID                                          ...
# 88525     Regular Air  Central          Illinois  ...       60101   5/28/2012
# 88522     Express Air     West        Washington  ...       98221    7/7/2010
# 88523     Express Air     West        Washington  ...       98221   7/27/2011
# 88523     Regular Air     West        Washington  ...       98221   7/27/2011
# 88523     Express Air     West        Washington  ...       98221   7/27/2011
#
#           Ship Date Quantity Ordered  Unit Price  Discount  \
# Order ID
# 88525     5/30/2012                2        2.88      0.01
# 88522      7/8/2010                4        2.84      0.01
# 88523     7/28/2011                7        6.68      0.03
# 88523     7/28/2011                7        5.68      0.01
# 88523     7/27/2011                8      205.99      0.00
#
#           Product Base Margin  Shipping Cost    Sales    Profit
# Order ID
# 88525                    0.36           0.50     5.90    1.3200
# 88522                    0.54           0.93    13.01    4.5600
# 88523                    0.37           6.15    49.92  -47.6400
# 88523                    0.56           3.60    41.64  -30.5100
# 88523                    0.59           2.50  1446.67  998.2023
#
# [5 rows x 21 columns]

# %%
# @title Rows & Columns

print("Rows:", df_orders.shape[0])
print("Columns:", df_orders.shape[1])
# Out:
# Rows: 9427
# Columns: 21

# %%
# @title Dataset Columns

# Let's print the columns (features) names.
df_orders.columns
# Out:
# Index(['Customer ID', 'Customer Segment', 'Product Category',
#        'Product Sub-Category', 'Product Container', 'Product Name',
#        'Order Priority', 'Ship Mode', 'Region', 'State or Province', 'City',
#        'Postal Code', 'Order Date', 'Ship Date', 'Quantity Ordered',
#        'Unit Price', 'Discount', 'Product Base Margin', 'Shipping Cost',
#        'Sales', 'Profit'],
#       dtype='object')

# %%
# @title Columns Data Type

# Let's print the columns data types.
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9427 entries, 88525 to 87533
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           9427 non-null   int64
#  1   Customer Segment      9427 non-null   object
#  2   Product Category      9427 non-null   object
#  3   Product Sub-Category  9427 non-null   object
#  4   Product Container     9427 non-null   object
#  5   Product Name          9427 non-null   object
#  6   Order Priority        9427 non-null   object
#  7   Ship Mode             9427 non-null   object
#  8   Region                9427 non-null   object
#  9   State or Province     9427 non-null   object
#  10  City                  9427 non-null   object
#  11  Postal Code           9427 non-null   int64
#  12  Order Date            9427 non-null   object
#  13  Ship Date             9427 non-null   object
#  14  Quantity Ordered      9427 non-null   int64
#  15  Unit Price            9427 non-null   float64
#  16  Discount              9427 non-null   float64
#  17  Product Base Margin   9355 non-null   float64
#  18  Shipping Cost         9427 non-null   float64
#  19  Sales                 9427 non-null   float64
#  20  Profit                9427 non-null   float64
# dtypes: float64(6), int64(3), object(12)
# memory usage: 1.6+ MB

# %%
# @title Columns Data Type Correcting

# Let's try to change the datatypes of the following column in the dataset.
df_orders['Order Date'] = df_orders['Order Date'].astype('datetime64[ns]')
df_orders['Ship Date'] = df_orders['Ship Date'].astype('datetime64[ns]')
df_orders['Postal Code'] = df_orders['Postal Code'].astype('object')


# Let's print the columns data types.
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9427 entries, 88525 to 87533
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           9427 non-null   int64
#  1   Customer Segment      9427 non-null   object
#  2   Product Category      9427 non-null   object
#  3   Product Sub-Category  9427 non-null   object
#  4   Product Container     9427 non-null   object
#  5   Product Name          9427 non-null   object
#  6   Order Priority        9427 non-null   object
#  7   Ship Mode             9427 non-null   object
#  8   Region                9427 non-null   object
#  9   State or Province     9427 non-null   object
#  10  City                  9427 non-null   object
#  11  Postal Code           9427 non-null   object
#  12  Order Date            9427 non-null   datetime64[ns]
#  13  Ship Date             9427 non-null   datetime64[ns]
#  14  Quantity Ordered      9427 non-null   int64
#  15  Unit Price            9427 non-null   float64
#  16  Discount              9427 non-null   float64
#  17  Product Base Margin   9355 non-null   float64
#  18  Shipping Cost         9427 non-null   float64
#  19  Sales                 9427 non-null   float64
#  20  Profit                9427 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(2), object(11)
# memory usage: 1.6+ MB

# %%
# @title Dataset Statistic Figures

# Describing statistical information on the dataset
df_orders.describe()
# Out:
#        Customer ID                     Order Date  \
# count  9427.000000                           9427
# mean   1738.238464  2012-03-05 19:19:32.759096064
# min       2.000000            2010-01-01 00:00:00
# 25%     898.000000            2011-03-07 12:00:00
# 50%    1750.000000            2012-04-08 00:00:00
# 75%    2578.500000            2013-03-26 00:00:00
# max    3403.000000            2013-12-31 00:00:00
# std     979.277823                            NaN
#
#                            Ship Date  Quantity Ordered   Unit Price  \
# count                           9427       9427.000000  9427.000000
# mean   2012-03-07 20:01:51.509494016         13.797390    88.295006
# min              2010-01-02 00:00:00          1.000000     0.990000
# 25%              2011-03-09 00:00:00          5.000000     6.480000
# 50%              2012-04-09 00:00:00         10.000000    20.990000
# 75%              2013-03-28 00:00:00         17.000000    85.990000
# max              2014-01-17 00:00:00        170.000000  6783.020000
# std                              NaN         15.107223   281.527308
#
#           Discount  Product Base Margin  Shipping Cost          Sales  \
# count  9427.000000          9355.000000    9427.000000    9427.000000
# mean      0.049630             0.512174      12.794485     949.599889
# min       0.000000             0.350000       0.490000       1.320000
# 25%       0.020000             0.380000       3.215000      61.100000
# 50%       0.050000             0.520000       6.050000     203.420000
# 75%       0.080000             0.590000      13.990000     776.355000
# max       0.250000             0.850000     164.730000  100119.160000
# std       0.031797             0.135230      17.180410    2597.902183
#
#              Profit
# count   9427.000000
# mean     139.220170
# min   -16476.838000
# 25%      -74.004750
# 50%        2.539200
# 75%      140.207700
# max    16332.414000
# std      998.434762

# %%
# Describing more statistical information on the dataset
df_orders.describe(include='all')
# Out:
#         Customer ID Customer Segment Product Category Product Sub-Category  \
# count   9427.000000             9427             9427                 9427
# unique          NaN                4                3                   17
# top             NaN        Corporate  Office Supplies                Paper
# freq            NaN             3375             5182                 1380
# mean    1738.238464              NaN              NaN                  NaN
# min        2.000000              NaN              NaN                  NaN
# 25%      898.000000              NaN              NaN                  NaN
# 50%     1750.000000              NaN              NaN                  NaN
# 75%     2578.500000              NaN              NaN                  NaN
# max     3403.000000              NaN              NaN                  NaN
# std      979.277823              NaN              NaN                  NaN
#
#        Product Container                               Product Name  \
# count               9427                                       9427
# unique                 7                                       1263
# top            Small Box  Global High-Back Leather Tilter, Burgundy
# freq                4888                                         27
# mean                 NaN                                        NaN
# min                  NaN                                        NaN
# 25%                  NaN                                        NaN
# 50%                  NaN                                        NaN
# 75%                  NaN                                        NaN
# max                  NaN                                        NaN
# std                  NaN                                        NaN
#
#        Order Priority    Ship Mode   Region State or Province  ...  \
# count            9427         9427     9427              9427  ...
# unique              6            3        4                49  ...
# top              High  Regular Air  Central        California  ...
# freq             1970         7037     2899              1022  ...
# mean              NaN          NaN      NaN               NaN  ...
# min               NaN          NaN      NaN               NaN  ...
# 25%               NaN          NaN      NaN               NaN  ...
# 50%               NaN          NaN      NaN               NaN  ...
# 75%               NaN          NaN      NaN               NaN  ...
# max               NaN          NaN      NaN               NaN  ...
# std               NaN          NaN      NaN               NaN  ...
#
#        Postal Code                     Order Date  \
# count       9427.0                           9427
# unique      1697.0                            NaN
# top        10177.0                            NaN
# freq          54.0                            NaN
# mean           NaN  2012-03-05 19:19:32.759096064
# min            NaN            2010-01-01 00:00:00
# 25%            NaN            2011-03-07 12:00:00
# 50%            NaN            2012-04-08 00:00:00
# 75%            NaN            2013-03-26 00:00:00
# max            NaN            2013-12-31 00:00:00
# std            NaN                            NaN
#
#                             Ship Date Quantity Ordered   Unit Price  \
# count                            9427      9427.000000  9427.000000
# unique                            NaN              NaN          NaN
# top                               NaN              NaN          NaN
# freq                              NaN              NaN          NaN
# mean    2012-03-07 20:01:51.509494016        13.797390    88.295006
# min               2010-01-02 00:00:00         1.000000     0.990000
# 25%               2011-03-09 00:00:00         5.000000     6.480000
# 50%               2012-04-09 00:00:00        10.000000    20.990000
# 75%               2013-03-28 00:00:00        17.000000    85.990000
# max               2014-01-17 00:00:00       170.000000  6783.020000
# std                               NaN        15.107223   281.527308
#
#            Discount  Product Base Margin  Shipping Cost          Sales  \
# count   9427.000000          9355.000000    9427.000000    9427.000000
# unique          NaN                  NaN            NaN            NaN
# top             NaN                  NaN            NaN            NaN
# freq            NaN                  NaN            NaN            NaN
# mean       0.049630             0.512174      12.794485     949.599889
# min        0.000000             0.350000       0.490000       1.320000
# 25%        0.020000             0.380000       3.215000      61.100000
# 50%        0.050000             0.520000       6.050000     203.420000
# 75%        0.080000             0.590000      13.990000     776.355000
# max        0.250000             0.850000     164.730000  100119.160000
# std        0.031797             0.135230      17.180410    2597.902183
#
#               Profit
# count    9427.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      139.220170
# min    -16476.838000
# 25%       -74.004750
# 50%         2.539200
# 75%       140.207700
# max     16332.414000
# std       998.434762
#
# [11 rows x 21 columns]

# %%
# @title Exporting the modified Dataset

df_orders.to_csv('df_orders_exported.csv')
# index =False)

# %% [markdown]
# # **Data Cleaning**

# %%
# @title Reading Data
# Let's try to read from the new order dataset
df_cleaned = pd.read_csv('/content/df_orders_exported.csv')
df_cleaned.head()
# Out:
#    Order ID  Customer ID Customer Segment Product Category  \
# 0     88525            2        Corporate  Office Supplies
# 1     88522            3        Corporate  Office Supplies
# 2     88523            3        Corporate  Office Supplies
# 3     88523            3        Corporate  Office Supplies
# 4     88523            3        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name Order Priority    Ship Mode  \
# 0                                        Avery 49  Not Specified  Regular Air
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters           High  Express Air
# 2                                      Xerox 1968  Not Specified  Express Air
# 3        Acme® Preferred Stainless Steel Scissors  Not Specified  Regular Air
# 4                                             V70  Not Specified  Express Air
#
#     Region  ... Postal Code  Order Date   Ship Date Quantity Ordered  \
# 0  Central  ...       60101  2012-05-28  2012-05-30                2
# 1     West  ...       98221  2010-07-07  2010-07-08                4
# 2     West  ...       98221  2011-07-27  2011-07-28                7
# 3     West  ...       98221  2011-07-27  2011-07-28                7
# 4     West  ...       98221  2011-07-27  2011-07-27                8
#
#   Unit Price  Discount  Product Base Margin  Shipping Cost    Sales    Profit
# 0       2.88      0.01                 0.36           0.50     5.90    1.3200
# 1       2.84      0.01                 0.54           0.93    13.01    4.5600
# 2       6.68      0.03                 0.37           6.15    49.92  -47.6400
# 3       5.68      0.01                 0.56           3.60    41.64  -30.5100
# 4     205.99      0.00                 0.59           2.50  1446.67  998.2023
#
# [5 rows x 22 columns]

# %%
# @title Missing values check
# Let's try to read from the new order dataset
df_cleaned.isnull().sum()
# Out:
# Order ID                 0
# Customer ID              0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Order Priority           0
# Ship Mode                0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Quantity Ordered         0
# Unit Price               0
# Discount                 0
# Product Base Margin     72
# Shipping Cost            0
# Sales                    0
# Profit                   0
# dtype: int64

# %%
# @title Duplicate Checking

df_cleaned.duplicated().sum()
# Out:
# 1

# %%
# @title Removing Duplicate

df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **Merge & Consolidated Data**

# %%
# @title Merge with Customers

# Merge orders with customers on 'Customer ID'
df_consolidated = pd.merge(df_cleaned, df_customers, on='Customer ID', how='left')

# %%
# @title Merge with Regions

# Assuming there is a 'Region' column in df_orders to join with df_users
df_consolidated = pd.merge(df_consolidated, df_users, left_on='Region', right_on='Region', how='left')

# %%
# @title Merge with Returns

# Merge the result with returns on 'Order ID' to include order status
df_consolidated = pd.merge(df_consolidated, df_returns, on='Order ID', how='left')

# %%
# @title Consolidated Data

# The final df_consolidated will contain merged data
df_consolidated.head()
# Out:
#    Order ID  Customer ID Customer Segment Product Category  \
# 0     88525            2        Corporate  Office Supplies
# 1     88522            3        Corporate  Office Supplies
# 2     88523            3        Corporate  Office Supplies
# 3     88523            3        Corporate  Office Supplies
# 4     88523            3        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name Order Priority    Ship Mode  \
# 0                                        Avery 49  Not Specified  Regular Air
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters           High  Express Air
# 2                                      Xerox 1968  Not Specified  Express Air
# 3        Acme® Preferred Stainless Steel Scissors  Not Specified  Regular Air
# 4                                             V70  Not Specified  Express Air
#
#     Region  ... Quantity Ordered Unit Price  Discount Product Base Margin  \
# 0  Central  ...                2       2.88      0.01                0.36
# 1     West  ...                4       2.84      0.01                0.54
# 2     West  ...                7       6.68      0.03                0.37
# 3     West  ...                7       5.68      0.01                0.56
# 4     West  ...                8     205.99      0.00                0.59
#
#   Shipping Cost    Sales    Profit    Customer Name  Manager  Status
# 0          0.50     5.90    1.3200  Janice Fletcher    Chris     NaN
# 1          0.93    13.01    4.5600    Bonnie Potter  William     NaN
# 2          6.15    49.92  -47.6400    Bonnie Potter  William     NaN
# 3          3.60    41.64  -30.5100    Bonnie Potter  William     NaN
# 4          2.50  1446.67  998.2023    Bonnie Potter  William     NaN
#
# [5 rows x 25 columns]

# %%
# @title EDA of Consolidated Data

df_consolidated['Status'].value_counts(dropna=False)
# Out:
# Status
# NaN         9328
# Returned      98
# Name: count, dtype: int64

# %% [markdown]
# Lets Fill the NaN as 'Order Complete'

# %%
df_consolidated['Status'] = df_consolidated['Status'].fillna('Order Complete')

# %%
df_consolidated['Status'].value_counts(dropna=False)
# Out:
# Status
# Order Complete    9328
# Returned            98
# Name: count, dtype: int64

# %% [markdown]
# # **Store the Data in BigQuery**

# %%
# @title BigQuery

df_consolidated.to_gbq('Assignment.superstore_sales_data',
                     project_id,
                     chunksize=None,
                     if_exists='replace'
                     )
# Out:
# <ipython-input-27-07ed9e1a7574>:3: FutureWarning: Starting with pandas version 3.0 all arguments of to_gbq except for the argument 'destination_table' will be keyword-only.
#   df_consolidated.to_gbq('Assignment.superstore_sales_data',
# <ipython-input-27-07ed9e1a7574>:3: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   df_consolidated.to_gbq('Assignment.superstore_sales_data',
# 100%|██████████| 1/1 [00:00<00:00, 6820.01it/s]
